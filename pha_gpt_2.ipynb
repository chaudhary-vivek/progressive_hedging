# %%
import numpy as np
from scipy.optimize import minimize

class SupplyChainPH:
    def __init__(self, num_facilities, num_customers, num_scenarios, fixed_costs, transport_costs, capacities, demands, probabilities, rho=1.0):
        self.num_facilities = num_facilities
        self.num_customers = num_customers
        self.num_scenarios = num_scenarios
        self.fixed_costs = fixed_costs
        self.transport_costs = transport_costs
        self.capacities = capacities
        self.demands = demands
        self.probabilities = probabilities
        self.rho = rho

        # Initialize variables
        self.x = np.random.rand(num_scenarios, num_facilities, num_customers)
        self.w = np.zeros((num_scenarios, num_facilities, num_customers))
        self.z = np.mean(self.x, axis=0)

    def scenario_subproblem(self, scenario):
        def objective(x):
            x_reshaped = x.reshape(self.num_facilities, self.num_customers)
            fixed_cost = np.sum(self.fixed_costs * (np.sum(x_reshaped, axis=1) > 0))
            transport_cost = np.sum(self.transport_costs * x_reshaped)
            augmented_lagrangian = np.sum(self.w[scenario] * (x_reshaped - self.z)) + \
                                   (self.rho/2) * np.sum((x_reshaped - self.z)**2)
            return fixed_cost + transport_cost + augmented_lagrangian

        def constraints(x):
            x_reshaped = x.reshape(self.num_facilities, self.num_customers)
            capacity_constraint = self.capacities - np.sum(x_reshaped, axis=1)
            demand_constraint = np.sum(x_reshaped, axis=0) - self.demands[scenario]
            return np.concatenate([capacity_constraint, demand_constraint])

        x0 = self.x[scenario].flatten()
        cons = {'type': 'ineq', 'fun': constraints}
        bounds = [(0, None) for _ in range(self.num_facilities * self.num_customers)]

        result = minimize(objective, x0, method='SLSQP', bounds=bounds, constraints=cons)
        return result.x.reshape(self.num_facilities, self.num_customers)

    def calculate_objective(self, x):
        fixed_cost = np.sum(self.fixed_costs * (np.sum(x, axis=1) > 0))
        transport_cost = np.sum(self.transport_costs * x)
        return fixed_cost + transport_cost

    def solve(self, max_iterations=1000, tolerance=1e-4):
        for iteration in range(max_iterations):
            # Solve scenario subproblems
            for s in range(self.num_scenarios):
                self.x[s] = self.scenario_subproblem(s)

            # Compute new average solution
            z_new = np.average(self.x, axis=0, weights=self.probabilities)

            # Calculate and print objective value
            obj_value = np.sum([self.probabilities[s] * self.calculate_objective(self.x[s]) for s in range(self.num_scenarios)])
            print(f"Iteration {iteration+1}, Objective Value: {obj_value:.2f}")

            # Update price variables
            for s in range(self.num_scenarios):
                self.w[s] += self.rho * (self.x[s] - z_new)

            # Check convergence
            if np.max(np.abs(z_new - self.z)) < tolerance:
                break

            self.z = z_new

        final_obj_value = self.calculate_objective(self.z)
        print(f"\nFinal Objective Value: {final_obj_value:.2f}")
        return self.z

# Example usage
np.random.seed(42)  # for reproducibility
num_facilities = 3
num_customers = 5
num_scenarios = 3

fixed_costs = np.array([100000, 120000, 90000])
transport_costs = np.random.rand(num_facilities, num_customers) * 100
capacities = np.array([5000, 6000, 4500])
demands = np.random.randint(500, 1500, size=(num_scenarios, num_customers))
probabilities = np.array([0.3, 0.5, 0.2])

ph_solver = SupplyChainPH(num_facilities, num_customers, num_scenarios, 
                          fixed_costs, transport_costs, capacities, demands, probabilities)

solution = ph_solver.solve()

print("\nOptimal facility allocations:")
print(solution)
print("\nFacilities to open:")
print(np.where(np.sum(solution, axis=1) > 0)[0])
# Out:
# Iteration 1, Objective Value: 555423.39
# Iteration 2, Objective Value: 572566.87
# Iteration 3, Objective Value: 574556.58
# Iteration 4, Objective Value: 572047.39
# Iteration 5, Objective Value: 565863.42
# Iteration 6, Objective Value: 556861.62
# Iteration 7, Objective Value: 546683.37
# Iteration 8, Objective Value: 536574.18
# Iteration 9, Objective Value: 526994.69
# Iteration 10, Objective Value: 517734.77
# Iteration 11, Objective Value: 508461.08
# Iteration 12, Objective Value: 501169.43
# Iteration 13, Objective Value: 494223.16
# Iteration 14, Objective Value: 488554.09
# Iteration 15, Objective Value: 487003.05
# Iteration 16, Objective Value: 485576.55
# Iteration 17, Objective Value: 484088.33
# Iteration 18, Objective Value: 482628.52
# Iteration 19, Objective Value: 481240.32
# Iteration 20, Objective Value: 479940.00
# Iteration 21, Objective Value: 478727.02
# Iteration 22, Objective Value: 477593.31
# Iteration 23, Objective Value: 476507.16
# Iteration 24, Objective Value: 475430.94
# Iteration 25, Objective Value: 474333.37
# Iteration 26, Objective Value: 473196.83
# Iteration 27, Objective Value: 472017.50
# Iteration 28, Objective Value: 471635.78
# Iteration 29, Objective Value: 471496.07
# Iteration 30, Objective Value: 471164.20
# Iteration 31, Objective Value: 470789.37
# Iteration 32, Objective Value: 470472.27
# Iteration 33, Objective Value: 470239.62
# Iteration 34, Objective Value: 470069.08
# Iteration 35, Objective Value: 469922.55
# Iteration 36, Objective Value: 469772.10
# Iteration 37, Objective Value: 469606.39
# Iteration 38, Objective Value: 469426.41
# Iteration 39, Objective Value: 469237.68
# Iteration 40, Objective Value: 469045.02
# Iteration 41, Objective Value: 468850.48
# Iteration 42, Objective Value: 468653.89
# Iteration 43, Objective Value: 468455.09
# Iteration 44, Objective Value: 468255.35
# Iteration 45, Objective Value: 468055.47
# Iteration 46, Objective Value: 467857.38
# Iteration 47, Objective Value: 467662.15
# Iteration 48, Objective Value: 467469.92
# Iteration 49, Objective Value: 467280.07
# Iteration 50, Objective Value: 467091.83
# Iteration 51, Objective Value: 466903.52
# Iteration 52, Objective Value: 466714.75
# Iteration 53, Objective Value: 466524.27
# Iteration 54, Objective Value: 466332.98
# Iteration 55, Objective Value: 466140.04
# Iteration 56, Objective Value: 465946.04
# Iteration 57, Objective Value: 465751.40
# Iteration 58, Objective Value: 465628.32
# Iteration 59, Objective Value: 465531.73
# Iteration 60, Objective Value: 465430.06
# Iteration 61, Objective Value: 465325.41
# Iteration 62, Objective Value: 465220.88
# Iteration 63, Objective Value: 465116.66
# Iteration 64, Objective Value: 465013.55
# Iteration 65, Objective Value: 464912.35
# Iteration 66, Objective Value: 464812.24
# Iteration 67, Objective Value: 464713.18
# Iteration 68, Objective Value: 464614.21
# Iteration 69, Objective Value: 464514.55
# Iteration 70, Objective Value: 464414.37
# Iteration 71, Objective Value: 464313.28
# Iteration 72, Objective Value: 464211.78
# Iteration 73, Objective Value: 464109.82
# Iteration 74, Objective Value: 464008.38
# Iteration 75, Objective Value: 463907.51
# Iteration 76, Objective Value: 463806.84
# Iteration 77, Objective Value: 463706.08
# Iteration 78, Objective Value: 463605.63
# Iteration 79, Objective Value: 463505.04
# Iteration 80, Objective Value: 463404.92
# Iteration 81, Objective Value: 463373.80
# Iteration 82, Objective Value: 463481.67
# Iteration 83, Objective Value: 463399.11
# Iteration 84, Objective Value: 463235.77
# Iteration 85, Objective Value: 463086.51
# Iteration 86, Objective Value: 462992.28
# Iteration 87, Objective Value: 462945.49
# Iteration 88, Objective Value: 462919.03
# Iteration 89, Objective Value: 462889.22
# Iteration 90, Objective Value: 462845.69
# Iteration 91, Objective Value: 462790.24
# Iteration 92, Objective Value: 462729.64
# Iteration 93, Objective Value: 462669.88
# Iteration 94, Objective Value: 462613.51
# Iteration 95, Objective Value: 462560.13
# Iteration 96, Objective Value: 462508.12
# Iteration 97, Objective Value: 462455.75
# Iteration 98, Objective Value: 462402.47
# Iteration 99, Objective Value: 462348.72
# Iteration 100, Objective Value: 462294.51
# Iteration 101, Objective Value: 462240.41
# Iteration 102, Objective Value: 462186.38
# Iteration 103, Objective Value: 462132.60
# Iteration 104, Objective Value: 462078.88
# Iteration 105, Objective Value: 462025.34
# Iteration 106, Objective Value: 461971.59
# Iteration 107, Objective Value: 461917.77
# Iteration 108, Objective Value: 461863.85
# Iteration 109, Objective Value: 461810.17
# Iteration 110, Objective Value: 461756.47
# Iteration 111, Objective Value: 461702.61
# Iteration 112, Objective Value: 461648.81
# Iteration 113, Objective Value: 461594.97
# Iteration 114, Objective Value: 461541.34
# Iteration 115, Objective Value: 461487.51
# Iteration 116, Objective Value: 461433.65
# Iteration 117, Objective Value: 461379.87
# Iteration 118, Objective Value: 461326.16
# Iteration 119, Objective Value: 461272.34
# Iteration 120, Objective Value: 461218.62
# Iteration 121, Objective Value: 461164.68
# Iteration 122, Objective Value: 461110.95
# Iteration 123, Objective Value: 461057.28
# Iteration 124, Objective Value: 461003.49
# Iteration 125, Objective Value: 460949.58
# Iteration 126, Objective Value: 460895.89
# Iteration 127, Objective Value: 460841.89
# Iteration 128, Objective Value: 460788.30
# Iteration 129, Objective Value: 460734.59
# Iteration 130, Objective Value: 460680.79
# Iteration 131, Objective Value: 460627.12
# Iteration 132, Objective Value: 460573.31
# Iteration 133, Objective Value: 460519.25
# Iteration 134, Objective Value: 460465.60
# Iteration 135, Objective Value: 460411.94
# Iteration 136, Objective Value: 460590.06
# Iteration 137, Objective Value: 460588.53
# Iteration 138, Objective Value: 460494.14
# Iteration 139, Objective Value: 460398.98
# Iteration 140, Objective Value: 460349.28
# Iteration 141, Objective Value: 460345.51
# Iteration 142, Objective Value: 460364.91
# Iteration 143, Objective Value: 460384.49
# Iteration 144, Objective Value: 460392.74
# Iteration 145, Objective Value: 460389.66
# Iteration 146, Objective Value: 460380.52
# Iteration 147, Objective Value: 460371.32
# Iteration 148, Objective Value: 460365.10
# Iteration 149, Objective Value: 460361.80
# Iteration 150, Objective Value: 460360.10
# Iteration 151, Objective Value: 460358.26
# Iteration 152, Objective Value: 460355.70
# Iteration 153, Objective Value: 460352.18
# Iteration 154, Objective Value: 460348.43
# Iteration 155, Objective Value: 460344.74
# Iteration 156, Objective Value: 460341.22
# Iteration 157, Objective Value: 460338.00
# Iteration 158, Objective Value: 460334.77
# Iteration 159, Objective Value: 460331.49
# Iteration 160, Objective Value: 460328.17
# Iteration 161, Objective Value: 460324.82
# Iteration 162, Objective Value: 460321.55
# Iteration 163, Objective Value: 460318.13
# Iteration 164, Objective Value: 460314.68
# Iteration 165, Objective Value: 460311.42
# Iteration 166, Objective Value: 460308.13
# Iteration 167, Objective Value: 460304.89
# Iteration 168, Objective Value: 460301.49
# Iteration 169, Objective Value: 460298.24
# Iteration 170, Objective Value: 460294.96
# Iteration 171, Objective Value: 460291.56
# Iteration 172, Objective Value: 460288.22
# Iteration 173, Objective Value: 460284.94
# Iteration 174, Objective Value: 460281.52
# Iteration 175, Objective Value: 460278.05
# Iteration 176, Objective Value: 460274.83
# Iteration 177, Objective Value: 460271.47
# Iteration 178, Objective Value: 460268.17
# Iteration 179, Objective Value: 460264.85
# Iteration 180, Objective Value: 460261.42
# Iteration 181, Objective Value: 460258.22
# Iteration 182, Objective Value: 460254.95
# Iteration 183, Objective Value: 460251.74
# Iteration 184, Objective Value: 460248.42
# Iteration 185, Objective Value: 460245.02
# Iteration 186, Objective Value: 460241.51
# Iteration 187, Objective Value: 460237.98
# Iteration 188, Objective Value: 460234.74
# Iteration 189, Objective Value: 460231.54
# Iteration 190, Objective Value: 460228.21
# Iteration 191, Objective Value: 460224.94
# Iteration 192, Objective Value: 460221.75
# Iteration 193, Objective Value: 460218.42
# Iteration 194, Objective Value: 460214.96
# Iteration 195, Objective Value: 460211.59
# Iteration 196, Objective Value: 460208.36
# Iteration 197, Objective Value: 460204.92
# Iteration 198, Objective Value: 460201.75
# Iteration 199, Objective Value: 460198.24
# Iteration 200, Objective Value: 460194.79
# Iteration 201, Objective Value: 460191.53
# Iteration 202, Objective Value: 460188.14
# Iteration 203, Objective Value: 460184.86
# Iteration 204, Objective Value: 460181.59
# Iteration 205, Objective Value: 460178.31
# Iteration 206, Objective Value: 460174.99
# Iteration 207, Objective Value: 460171.73
# Iteration 208, Objective Value: 460168.30
# Iteration 209, Objective Value: 460164.93
# Iteration 210, Objective Value: 460161.67
# Iteration 211, Objective Value: 460158.41
# Iteration 212, Objective Value: 460155.05
# Iteration 213, Objective Value: 460151.72
# Iteration 214, Objective Value: 460148.35
# Iteration 215, Objective Value: 460144.90
# Iteration 216, Objective Value: 460141.63
# Iteration 217, Objective Value: 460138.21
# Iteration 218, Objective Value: 460134.86
# Iteration 219, Objective Value: 460131.74
# Iteration 220, Objective Value: 460128.37
# Iteration 221, Objective Value: 460125.08
# Iteration 222, Objective Value: 460121.72
# Iteration 223, Objective Value: 460118.27
# Iteration 224, Objective Value: 460114.99
# Iteration 225, Objective Value: 460111.74
# Iteration 226, Objective Value: 460108.41
# Iteration 227, Objective Value: 460105.13
# Iteration 228, Objective Value: 460101.71
# Iteration 229, Objective Value: 460098.33
# Iteration 230, Objective Value: 460095.05
# Iteration 231, Objective Value: 460091.73
# Iteration 232, Objective Value: 460088.41
# Iteration 233, Objective Value: 460084.98
# Iteration 234, Objective Value: 460081.79
# Iteration 235, Objective Value: 460078.38
# Iteration 236, Objective Value: 460075.09
# Iteration 237, Objective Value: 460071.76
# Iteration 238, Objective Value: 460068.41
# Iteration 239, Objective Value: 460065.04
# Iteration 240, Objective Value: 460061.70
# Iteration 241, Objective Value: 460058.40
# Iteration 242, Objective Value: 460055.10
# Iteration 243, Objective Value: 460051.83
# Iteration 244, Objective Value: 460048.40
# Iteration 245, Objective Value: 460045.05
# Iteration 246, Objective Value: 460041.79
# Iteration 247, Objective Value: 460038.47
# Iteration 248, Objective Value: 460035.17
# Iteration 249, Objective Value: 460031.77
# Iteration 250, Objective Value: 460028.36
# Iteration 251, Objective Value: 460025.09
# Iteration 252, Objective Value: 460021.71
# Iteration 253, Objective Value: 460018.46
# Iteration 254, Objective Value: 460015.21
# Iteration 255, Objective Value: 460011.85
# Iteration 256, Objective Value: 460008.52
# Iteration 257, Objective Value: 460005.23
# Iteration 258, Objective Value: 460001.80
# Iteration 259, Objective Value: 459998.47
# Iteration 260, Objective Value: 459995.03
# Iteration 261, Objective Value: 459991.78
# Iteration 262, Objective Value: 459988.51
# Iteration 263, Objective Value: 459985.20
# Iteration 264, Objective Value: 459981.88
# Iteration 265, Objective Value: 459978.66
# Iteration 266, Objective Value: 459975.20
# Iteration 267, Objective Value: 459971.79
# Iteration 268, Objective Value: 459968.42
# Iteration 269, Objective Value: 459965.09
# Iteration 270, Objective Value: 459961.84
# Iteration 271, Objective Value: 459958.54
# Iteration 272, Objective Value: 459955.26
# Iteration 273, Objective Value: 459951.83
# Iteration 274, Objective Value: 459948.56
# Iteration 275, Objective Value: 459945.15
# Iteration 276, Objective Value: 459941.83
# Iteration 277, Objective Value: 459938.55
# Iteration 278, Objective Value: 459935.33
# Iteration 279, Objective Value: 459931.94
# Iteration 280, Objective Value: 459928.54
# Iteration 281, Objective Value: 459925.18
# Iteration 282, Objective Value: 459921.84
# Iteration 283, Objective Value: 459918.49
# Iteration 284, Objective Value: 459915.22
# Iteration 285, Objective Value: 459911.91
# Iteration 286, Objective Value: 459908.59
# Iteration 287, Objective Value: 459905.26
# Iteration 288, Objective Value: 459901.94
# Iteration 289, Objective Value: 459898.74
# Iteration 290, Objective Value: 459895.24
# Iteration 291, Objective Value: 459891.75
# Iteration 292, Objective Value: 459888.53
# Iteration 293, Objective Value: 459885.29
# Iteration 294, Objective Value: 459881.89
# Iteration 295, Objective Value: 459878.53
# Iteration 296, Objective Value: 459875.26
# Iteration 297, Objective Value: 459871.93
# Iteration 298, Objective Value: 459868.64
# Iteration 299, Objective Value: 459865.33
# Iteration 300, Objective Value: 459861.97
# Iteration 301, Objective Value: 459858.46
# Iteration 302, Objective Value: 459855.33
# Iteration 303, Objective Value: 459851.94
# Iteration 304, Objective Value: 459848.77
# Iteration 305, Objective Value: 459845.37
# Iteration 306, Objective Value: 459841.98
# Iteration 307, Objective Value: 459838.64
# Iteration 308, Objective Value: 459835.40
# Iteration 309, Objective Value: 459831.98
# Iteration 310, Objective Value: 459828.67
# Iteration 311, Objective Value: 459825.32
# Iteration 312, Objective Value: 459821.88
# Iteration 313, Objective Value: 459818.59
# Iteration 314, Objective Value: 459815.27
# Iteration 315, Objective Value: 459811.92
# Iteration 316, Objective Value: 459808.59
# Iteration 317, Objective Value: 459805.39
# Iteration 318, Objective Value: 459802.12
# Iteration 319, Objective Value: 459798.80
# Iteration 320, Objective Value: 459795.38
# Iteration 321, Objective Value: 459792.06
# Iteration 322, Objective Value: 459788.67
# Iteration 323, Objective Value: 459785.47
# Iteration 324, Objective Value: 459782.10
# Iteration 325, Objective Value: 459778.62
# Iteration 326, Objective Value: 459775.32
# Iteration 327, Objective Value: 459771.97
# Iteration 328, Objective Value: 459768.61
# Iteration 329, Objective Value: 459765.39
# Iteration 330, Objective Value: 459762.00
# Iteration 331, Objective Value: 459758.63
# Iteration 332, Objective Value: 459755.39
# Iteration 333, Objective Value: 459752.15
# Iteration 334, Objective Value: 459748.82
# Iteration 335, Objective Value: 459745.37
# Iteration 336, Objective Value: 459742.00
# Iteration 337, Objective Value: 459738.79
# Iteration 338, Objective Value: 459735.52
# Iteration 339, Objective Value: 459732.19
# Iteration 340, Objective Value: 459728.84
# Iteration 341, Objective Value: 459725.36
# Iteration 342, Objective Value: 459721.96
# Iteration 343, Objective Value: 459718.68
# Iteration 344, Objective Value: 459715.35
# Iteration 345, Objective Value: 459712.12
# Iteration 346, Objective Value: 459708.75
# Iteration 347, Objective Value: 459705.49
# Iteration 348, Objective Value: 459702.16
# Iteration 349, Objective Value: 459698.83
# Iteration 350, Objective Value: 459695.54
# Iteration 351, Objective Value: 459692.07
# Iteration 352, Objective Value: 459688.83
# Iteration 353, Objective Value: 459685.45
# Iteration 354, Objective Value: 459682.05
# Iteration 355, Objective Value: 459678.76
# Iteration 356, Objective Value: 459675.47
# Iteration 357, Objective Value: 459672.08
# Iteration 358, Objective Value: 459668.67
# Iteration 359, Objective Value: 459665.38
# Iteration 360, Objective Value: 459662.11
# Iteration 361, Objective Value: 459658.87
# Iteration 362, Objective Value: 459655.63
# Iteration 363, Objective Value: 459652.33
# Iteration 364, Objective Value: 459648.99
# Iteration 365, Objective Value: 459645.61
# Iteration 366, Objective Value: 459642.05
# Iteration 367, Objective Value: 459638.68
# Iteration 368, Objective Value: 459635.48
# Iteration 369, Objective Value: 459632.14
# Iteration 370, Objective Value: 459628.75
# Iteration 371, Objective Value: 459625.54
# Iteration 372, Objective Value: 459622.28
# Iteration 373, Objective Value: 459618.98
# Iteration 374, Objective Value: 459615.55
# Iteration 375, Objective Value: 459612.24
# Iteration 376, Objective Value: 459608.84
# Iteration 377, Objective Value: 459605.55
# Iteration 378, Objective Value: 459602.15
# Iteration 379, Objective Value: 459598.78
# Iteration 380, Objective Value: 459595.49
# Iteration 381, Objective Value: 459592.17
# Iteration 382, Objective Value: 459588.90
# Iteration 383, Objective Value: 459585.60
# Iteration 384, Objective Value: 459582.21
# Iteration 385, Objective Value: 459578.95
# Iteration 386, Objective Value: 459575.67
# Iteration 387, Objective Value: 459572.38
# Iteration 388, Objective Value: 459568.92
# Iteration 389, Objective Value: 459565.56
# Iteration 390, Objective Value: 459562.21
# Iteration 391, Objective Value: 459558.83
# Iteration 392, Objective Value: 459555.66
# Iteration 393, Objective Value: 459552.29
# Iteration 394, Objective Value: 459548.89
# Iteration 395, Objective Value: 459545.66
# Iteration 396, Objective Value: 459542.34
# Iteration 397, Objective Value: 459538.99
# Iteration 398, Objective Value: 459535.52
# Iteration 399, Objective Value: 459532.20
# Iteration 400, Objective Value: 459528.91
# Iteration 401, Objective Value: 459525.66
# Iteration 402, Objective Value: 459522.24
# Iteration 403, Objective Value: 459518.89
# Iteration 404, Objective Value: 459515.65
# Iteration 405, Objective Value: 459512.41
# Iteration 406, Objective Value: 459509.05
# Iteration 407, Objective Value: 459505.68
# Iteration 408, Objective Value: 459502.45
# Iteration 409, Objective Value: 459499.03
# Iteration 410, Objective Value: 459495.46
# Iteration 411, Objective Value: 459492.17
# Iteration 412, Objective Value: 459488.94
# Iteration 413, Objective Value: 459485.76
# Iteration 414, Objective Value: 459482.45
# Iteration 415, Objective Value: 459479.08
# Iteration 416, Objective Value: 459475.69
# Iteration 417, Objective Value: 459472.29
# Iteration 418, Objective Value: 459468.98
# Iteration 419, Objective Value: 459465.73
# Iteration 420, Objective Value: 459462.36
# Iteration 421, Objective Value: 459459.10
# Iteration 422, Objective Value: 459455.80
# Iteration 423, Objective Value: 459452.38
# Iteration 424, Objective Value: 459449.03
# Iteration 425, Objective Value: 459445.69
# Iteration 426, Objective Value: 459442.35
# Iteration 427, Objective Value: 459438.97
# Iteration 428, Objective Value: 459435.68
# Iteration 429, Objective Value: 459432.33
# Iteration 430, Objective Value: 459429.12
# Iteration 431, Objective Value: 459425.83
# Iteration 432, Objective Value: 459422.44
# Iteration 433, Objective Value: 459419.16
# Iteration 434, Objective Value: 459415.66
# Iteration 435, Objective Value: 459412.33
# Iteration 436, Objective Value: 459408.99
# Iteration 437, Objective Value: 459405.84
# Iteration 438, Objective Value: 459402.50
# Iteration 439, Objective Value: 459399.19
# Iteration 440, Objective Value: 459395.73
# Iteration 441, Objective Value: 459392.45
# Iteration 442, Objective Value: 459389.13
# Iteration 443, Objective Value: 459385.68
# Iteration 444, Objective Value: 459382.37
# Iteration 445, Objective Value: 459379.16
# Iteration 446, Objective Value: 459375.90
# Iteration 447, Objective Value: 459372.62
# Iteration 448, Objective Value: 459369.15
# Iteration 449, Objective Value: 459365.67
# Iteration 450, Objective Value: 459362.38
# Iteration 451, Objective Value: 459359.03
# Iteration 452, Objective Value: 459355.91
# Iteration 453, Objective Value: 459352.65
# Iteration 454, Objective Value: 459349.12
# Iteration 455, Objective Value: 459345.78
# Iteration 456, Objective Value: 459342.43
# Iteration 457, Objective Value: 459339.23
# Iteration 458, Objective Value: 459335.90
# Iteration 459, Objective Value: 459332.56
# Iteration 460, Objective Value: 459329.26
# Iteration 461, Objective Value: 459325.80
# Iteration 462, Objective Value: 459322.44
# Iteration 463, Objective Value: 459319.10
# Iteration 464, Objective Value: 459315.93
# Iteration 465, Objective Value: 459317.36
# Iteration 466, Objective Value: 459331.78
# Iteration 467, Objective Value: 459339.64
# Iteration 468, Objective Value: 459340.73
# Iteration 469, Objective Value: 459336.11
# Iteration 470, Objective Value: 459327.94
# Iteration 471, Objective Value: 459318.32
# Iteration 472, Objective Value: 459309.79
# Iteration 473, Objective Value: 459303.50
# Iteration 474, Objective Value: 459300.63
# Iteration 475, Objective Value: 459300.73
# Iteration 476, Objective Value: 459303.38
# Iteration 477, Objective Value: 459307.48
# Iteration 478, Objective Value: 459311.97
# Iteration 479, Objective Value: 459315.88
# Iteration 480, Objective Value: 459318.45
# Iteration 481, Objective Value: 459319.44
# Iteration 482, Objective Value: 459319.03
# Iteration 483, Objective Value: 459317.60
# Iteration 484, Objective Value: 459315.59
# Iteration 485, Objective Value: 459313.51
# Iteration 486, Objective Value: 459311.80
# Iteration 487, Objective Value: 459310.75
# Iteration 488, Objective Value: 459310.39
# Iteration 489, Objective Value: 459310.82
# Iteration 490, Objective Value: 459311.63
# Iteration 491, Objective Value: 459312.61
# Iteration 492, Objective Value: 459313.48
# Iteration 493, Objective Value: 459314.18
# Iteration 494, Objective Value: 459314.58
# Iteration 495, Objective Value: 459314.59
# Iteration 496, Objective Value: 459314.50
# Iteration 497, Objective Value: 459314.02
# Iteration 498, Objective Value: 459313.60
# Iteration 499, Objective Value: 459313.19
# Iteration 500, Objective Value: 459312.92
# Iteration 501, Objective Value: 459312.79
# Iteration 502, Objective Value: 459312.73
# Iteration 503, Objective Value: 459312.82
# Iteration 504, Objective Value: 459313.01
# Iteration 505, Objective Value: 459313.17
# Iteration 506, Objective Value: 459313.54
# Iteration 507, Objective Value: 459313.67
# Iteration 508, Objective Value: 459313.70
# Iteration 509, Objective Value: 459313.66
# Iteration 510, Objective Value: 459313.52
# Iteration 511, Objective Value: 459313.42
# Iteration 512, Objective Value: 459313.37
# Iteration 513, Objective Value: 459313.22
# Iteration 514, Objective Value: 459313.18
# Iteration 515, Objective Value: 459313.18
# Iteration 516, Objective Value: 459313.30
# Iteration 517, Objective Value: 459313.28
# Iteration 518, Objective Value: 459313.29
# Iteration 519, Objective Value: 459313.29
# Iteration 520, Objective Value: 459313.29
# Iteration 521, Objective Value: 459313.39
# Iteration 522, Objective Value: 459313.38
# Iteration 523, Objective Value: 459313.41
# Iteration 524, Objective Value: 459313.47
# Iteration 525, Objective Value: 459313.44
# Iteration 526, Objective Value: 459313.37
# Iteration 527, Objective Value: 459313.28
# Iteration 528, Objective Value: 459313.28
# Iteration 529, Objective Value: 459313.26
# Iteration 530, Objective Value: 459313.32
# Iteration 531, Objective Value: 459313.33
# Iteration 532, Objective Value: 459313.33
# Iteration 533, Objective Value: 459313.33
#
# Final Objective Value: 459313.33
#
# Optimal facility allocations:
# [[3.71207758e-11 5.32120780e-11 1.35600016e+03 2.02382293e-11
#   1.19899899e+03]
#  [1.35820240e-11 1.24699962e+03 8.84528037e-12 2.06129057e-11
#   2.74238781e-10]
#  [7.75998432e+02 4.92709457e-11 7.93678681e-12 1.05999969e+03
#   1.27368152e-10]]
#
# Facilities to open:
# [0 1 2]
