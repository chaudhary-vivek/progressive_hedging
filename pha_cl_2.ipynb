# %%
import numpy as np
from scipy.optimize import minimize

class SupplyChainPH:
    def __init__(self, num_facilities, num_customers, num_scenarios, fixed_costs, transport_costs, capacities, demands, probabilities, rho=1.0):
        self.num_facilities = num_facilities
        self.num_customers = num_customers
        self.num_scenarios = num_scenarios
        self.fixed_costs = fixed_costs
        self.transport_costs = transport_costs
        self.capacities = capacities
        self.demands = demands
        self.probabilities = probabilities
        self.rho = rho

        # Initialize variables
        self.x = np.random.rand(num_scenarios, num_facilities, num_customers)
        self.w = np.zeros((num_scenarios, num_facilities, num_customers))
        self.z = np.mean(self.x, axis=0)

    def scenario_subproblem(self, scenario):
        def objective(x):
            x_reshaped = x.reshape(self.num_facilities, self.num_customers)
            fixed_cost = np.sum(self.fixed_costs * (np.sum(x_reshaped, axis=1) > 0))
            transport_cost = np.sum(self.transport_costs * x_reshaped)
            augmented_lagrangian = np.sum(self.w[scenario] * (x_reshaped - self.z)) + \
                                   (self.rho/2) * np.sum((x_reshaped - self.z)**2)
            return fixed_cost + transport_cost + augmented_lagrangian

        def constraints(x):
            x_reshaped = x.reshape(self.num_facilities, self.num_customers)
            capacity_constraint = self.capacities - np.sum(x_reshaped, axis=1)
            demand_constraint = np.sum(x_reshaped, axis=0) - self.demands[scenario]
            return np.concatenate([capacity_constraint, demand_constraint])

        x0 = self.x[scenario].flatten()
        cons = {'type': 'ineq', 'fun': constraints}
        bounds = [(0, None) for _ in range(self.num_facilities * self.num_customers)]

        result = minimize(objective, x0, method='SLSQP', bounds=bounds, constraints=cons)
        return result.x.reshape(self.num_facilities, self.num_customers)

    def calculate_objective(self, x):
        fixed_cost = np.sum(self.fixed_costs * (np.sum(x, axis=1) > 0))
        transport_cost = np.sum(self.transport_costs * x)
        return fixed_cost + transport_cost

    def solve(self, max_iterations=100, tolerance=1e-4):
        for iteration in range(max_iterations):
            # Solve scenario subproblems
            for s in range(self.num_scenarios):
                self.x[s] = self.scenario_subproblem(s)

            # Compute new average solution
            z_new = np.average(self.x, axis=0, weights=self.probabilities)

            # Calculate and print objective value
            obj_value = np.sum([self.probabilities[s] * self.calculate_objective(self.x[s]) for s in range(self.num_scenarios)])
            print(f"Iteration {iteration+1}, Objective Value: {obj_value:.2f}")

            # Update price variables
            for s in range(self.num_scenarios):
                self.w[s] += self.rho * (self.x[s] - z_new)

            # Check convergence
            if np.max(np.abs(z_new - self.z)) < tolerance:
                break

            self.z = z_new

        final_obj_value = self.calculate_objective(self.z)
        print(f"\nFinal Objective Value: {final_obj_value:.2f}")
        return self.z

# Problem parameters
num_facilities = 3
num_customers = 5
num_scenarios = 100

# Fixed costs for opening facilities
fixed_costs = np.array([100000, 120000, 90000])

# Transportation costs from facilities to customers
trans_costs = np.array([
    [10, 15, 20, 25, 30],
    [12, 14, 18, 22, 26],
    [8, 16, 24, 32, 40]
])

# Facility capacities
capacities = np.array([5000, 6000, 4500])

# Generate random demand scenarios
np.random.seed(42)
demand_mean = 1000
demand_std = 200
demand_scenarios = np.random.normal(demand_mean, demand_std, (num_scenarios, num_customers))
demand_scenarios = np.clip(demand_scenarios, 0, None)  # Ensure non-negative demand

# Equal probabilities for all scenarios
probabilities = np.ones(num_scenarios) / num_scenarios

# Create and solve the problem
ph_solver = SupplyChainPH(num_facilities, num_customers, num_scenarios, 
                          fixed_costs, trans_costs, capacities, demand_scenarios, probabilities)

solution = ph_solver.solve(max_iterations=200, tolerance=1e-3)

print("\nOptimal facility allocations:")
print(solution)
print("\nFacilities to open:")
print(np.where(np.sum(solution, axis=1) > 0)[0])

# Calculate average allocation per facility
avg_allocation = np.sum(solution, axis=1)
print("\nAverage allocation per facility:")
for i, alloc in enumerate(avg_allocation):
    print(f"Facility {i}: {alloc:.2f}")

# Calculate average demand satisfaction
avg_demand = np.mean(demand_scenarios, axis=0)
avg_supply = np.sum(solution, axis=0)
print("\nAverage demand vs supply per customer:")
for i, (demand, supply) in enumerate(zip(avg_demand, avg_supply)):
    print(f"Customer {i}: Demand = {demand:.2f}, Supply = {supply:.2f}")
# Out:
# Iteration 1, Objective Value: 414036.04
# Iteration 2, Objective Value: 426747.17
# Iteration 3, Objective Value: 435667.35
# Iteration 4, Objective Value: 442221.88
# Iteration 5, Objective Value: 446942.74
# Iteration 6, Objective Value: 450504.59
# Iteration 7, Objective Value: 453246.23
# Iteration 8, Objective Value: 455308.74
# Iteration 9, Objective Value: 456818.14
# Iteration 10, Objective Value: 457856.48
# Iteration 11, Objective Value: 458500.93
# Iteration 12, Objective Value: 458878.89
# Iteration 13, Objective Value: 459070.76
# Iteration 14, Objective Value: 459116.22
# Iteration 15, Objective Value: 459049.94
# Iteration 16, Objective Value: 458891.56
# Iteration 17, Objective Value: 458688.11
# Iteration 18, Objective Value: 458451.21
# Iteration 19, Objective Value: 458180.52
# Iteration 20, Objective Value: 457883.31
# Iteration 21, Objective Value: 457676.72
# Iteration 22, Objective Value: 457579.22
# Iteration 23, Objective Value: 457581.14
# Iteration 24, Objective Value: 457666.82
# Iteration 25, Objective Value: 457823.44
# Iteration 26, Objective Value: 458033.62
# Iteration 27, Objective Value: 458280.45
# Iteration 28, Objective Value: 458558.15
# Iteration 29, Objective Value: 458861.79
# Iteration 30, Objective Value: 459191.25
# Iteration 31, Objective Value: 459542.74
# Iteration 32, Objective Value: 459911.16
# Iteration 33, Objective Value: 460282.02
# Iteration 34, Objective Value: 460641.20
# Iteration 35, Objective Value: 460975.23
# Iteration 36, Objective Value: 461285.01
# Iteration 37, Objective Value: 461567.69
# Iteration 38, Objective Value: 461813.41
# Iteration 39, Objective Value: 462013.56
# Iteration 40, Objective Value: 462161.02
# Iteration 41, Objective Value: 462254.83
# Iteration 42, Objective Value: 462291.90
# Iteration 43, Objective Value: 462270.11
# Iteration 44, Objective Value: 462229.91
# Iteration 45, Objective Value: 462185.31
# Iteration 46, Objective Value: 462136.41
# Iteration 47, Objective Value: 462089.53
# Iteration 48, Objective Value: 462044.66
# Iteration 49, Objective Value: 462001.52
# Iteration 50, Objective Value: 461959.76
# Iteration 51, Objective Value: 461918.64
# Iteration 52, Objective Value: 461877.37
# Iteration 53, Objective Value: 461834.80
# Iteration 54, Objective Value: 460988.44
# Iteration 55, Objective Value: 460564.13
# Iteration 56, Objective Value: 460164.53
# Iteration 57, Objective Value: 459799.68
# Iteration 58, Objective Value: 459472.34
# Iteration 59, Objective Value: 459184.21
# Iteration 60, Objective Value: 458936.05
# Iteration 61, Objective Value: 458727.58
# Iteration 62, Objective Value: 458557.69
# Iteration 63, Objective Value: 458424.68
# Iteration 64, Objective Value: 458325.99
# Iteration 65, Objective Value: 458258.67
# Iteration 66, Objective Value: 458219.25
# Iteration 67, Objective Value: 458207.31
# Iteration 68, Objective Value: 458220.11
# Iteration 69, Objective Value: 458252.78
# Iteration 70, Objective Value: 458300.21
# Iteration 71, Objective Value: 458357.14
# Iteration 72, Objective Value: 458418.27
# Iteration 73, Objective Value: 458478.36
# Iteration 74, Objective Value: 458532.68
# Iteration 75, Objective Value: 458577.42
# Iteration 76, Objective Value: 458728.79
# Iteration 77, Objective Value: 459078.71
# Iteration 78, Objective Value: 459401.91
# Iteration 79, Objective Value: 459692.91
# Iteration 80, Objective Value: 459946.95
# Iteration 81, Objective Value: 460159.88
# Iteration 82, Objective Value: 460328.20
# Iteration 83, Objective Value: 460449.15
# Iteration 84, Objective Value: 460534.36
# Iteration 85, Objective Value: 460605.02
# Iteration 86, Objective Value: 460660.81
# Iteration 87, Objective Value: 460701.14
# Iteration 88, Objective Value: 460725.43
# Iteration 89, Objective Value: 460732.83
# Iteration 90, Objective Value: 460722.44
# Iteration 91, Objective Value: 460693.25
# Iteration 92, Objective Value: 460644.07
# Iteration 93, Objective Value: 460573.85
# Iteration 94, Objective Value: 460481.40
# Iteration 95, Objective Value: 460365.64
# Iteration 96, Objective Value: 460225.76
# Iteration 97, Objective Value: 460061.53
# Iteration 98, Objective Value: 459872.60
# Iteration 99, Objective Value: 459659.29
# Iteration 100, Objective Value: 459422.05
# Iteration 101, Objective Value: 459310.50
# Iteration 102, Objective Value: 459195.77
# Iteration 103, Objective Value: 459055.88
# Iteration 104, Objective Value: 458891.20
# Iteration 105, Objective Value: 458702.65
# Iteration 106, Objective Value: 458491.59
# Iteration 107, Objective Value: 458259.82
# Iteration 108, Objective Value: 458009.67
# Iteration 109, Objective Value: 457743.87
# Iteration 110, Objective Value: 457465.96
# Iteration 111, Objective Value: 457178.96
# Iteration 112, Objective Value: 456886.23
# Iteration 113, Objective Value: 456591.38
# Iteration 114, Objective Value: 456303.37
# Iteration 115, Objective Value: 456026.52
# Iteration 116, Objective Value: 455763.75
# Iteration 117, Objective Value: 455517.69
# Iteration 118, Objective Value: 455290.72
# Iteration 119, Objective Value: 455084.85
# Iteration 120, Objective Value: 454901.76
# Iteration 121, Objective Value: 454742.82
# Iteration 122, Objective Value: 454609.02
# Iteration 123, Objective Value: 454500.88
# Iteration 124, Objective Value: 454418.65
# Iteration 125, Objective Value: 454362.24
# Iteration 126, Objective Value: 454331.11
# Iteration 127, Objective Value: 454324.52
# Iteration 128, Objective Value: 454341.37
# Iteration 129, Objective Value: 454380.30
# Iteration 130, Objective Value: 454439.70
# Iteration 131, Objective Value: 454518.53
# Iteration 132, Objective Value: 454615.75
# Iteration 133, Objective Value: 454729.38
# Iteration 134, Objective Value: 454857.33
# Iteration 135, Objective Value: 454997.41
# Iteration 136, Objective Value: 455147.29
# Iteration 137, Objective Value: 455304.65
# Iteration 138, Objective Value: 455467.08
# Iteration 139, Objective Value: 455632.36
# Iteration 140, Objective Value: 455798.33
# Iteration 141, Objective Value: 455967.66
# Iteration 142, Objective Value: 456191.73
# Iteration 143, Objective Value: 456425.37
# Iteration 144, Objective Value: 456654.42
# Iteration 145, Objective Value: 456877.04
# Iteration 146, Objective Value: 457091.36
# Iteration 147, Objective Value: 457295.12
# Iteration 148, Objective Value: 457486.20
# Iteration 149, Objective Value: 457662.75
# Iteration 150, Objective Value: 457823.05
# Iteration 151, Objective Value: 457965.50
# Iteration 152, Objective Value: 458088.87
# Iteration 153, Objective Value: 458191.30
# Iteration 154, Objective Value: 458272.58
# Iteration 155, Objective Value: 458331.66
# Iteration 156, Objective Value: 458367.89
# Iteration 157, Objective Value: 458380.90
# Iteration 158, Objective Value: 458370.50
# Iteration 159, Objective Value: 458336.70
# Iteration 160, Objective Value: 458279.78
# Iteration 161, Objective Value: 458200.13
# Iteration 162, Objective Value: 458098.43
# Iteration 163, Objective Value: 457975.57
# Iteration 164, Objective Value: 457832.59
# Iteration 165, Objective Value: 457670.73
# Iteration 166, Objective Value: 457491.45
# Iteration 167, Objective Value: 457296.35
# Iteration 168, Objective Value: 457087.14
# Iteration 169, Objective Value: 456865.76
# Iteration 170, Objective Value: 456634.19
# Iteration 171, Objective Value: 456394.55
# Iteration 172, Objective Value: 456149.02
# Iteration 173, Objective Value: 455899.86
# Iteration 174, Objective Value: 455649.32
# Iteration 175, Objective Value: 455399.71
# Iteration 176, Objective Value: 455153.31
# Iteration 177, Objective Value: 454912.33
# Iteration 178, Objective Value: 454678.97
# Iteration 179, Objective Value: 454455.28
# Iteration 180, Objective Value: 454243.33
# Iteration 181, Objective Value: 454044.92
# Iteration 182, Objective Value: 453861.74
# Iteration 183, Objective Value: 453695.36
# Iteration 184, Objective Value: 453547.11
# Iteration 185, Objective Value: 453418.13
# Iteration 186, Objective Value: 453309.35
# Iteration 187, Objective Value: 453221.52
# Iteration 188, Objective Value: 453155.19
# Iteration 189, Objective Value: 453110.53
# Iteration 190, Objective Value: 453087.53
# Iteration 191, Objective Value: 453086.05
# Iteration 192, Objective Value: 453105.61
# Iteration 193, Objective Value: 453145.56
# Iteration 194, Objective Value: 453205.06
# Iteration 195, Objective Value: 453282.97
# Iteration 196, Objective Value: 453378.04
# Iteration 197, Objective Value: 453488.89
# Iteration 198, Objective Value: 453613.88
# Iteration 199, Objective Value: 453751.35
# Iteration 200, Objective Value: 453899.45
#
# Final Objective Value: 453899.45
#
# Optimal facility allocations:
# [[4.89096437e+02 4.56067006e+02 5.00514588e+02 4.83762035e+02
#   4.95175617e+02]
#  [8.90662927e+01 6.60608877e+02 8.99412600e+02 1.08223079e+03
#   1.29512595e+03]
#  [8.89106473e+02 2.56619702e+02 3.85418995e-08 8.12962758e-11
#   1.28707516e-10]]
#
# Facilities to open:
# [0 1 2]
#
# Average allocation per facility:
# Facility 0: 2424.62
# Facility 1: 4026.44
# Facility 2: 1145.73
#
# Average demand vs supply per customer:
# Customer 0: Demand = 991.05, Supply = 1467.27
# Customer 1: Demand = 1015.39, Supply = 1373.30
# Customer 2: Demand = 981.23, Supply = 1399.93
# Customer 3: Demand = 1025.61, Supply = 1565.99
# Customer 4: Demand = 993.56, Supply = 1790.30

# %%
solution
# Out:
# array([[4.89096437e+02, 4.56067006e+02, 5.00514588e+02, 4.83762035e+02,
#         4.95175617e+02],
#        [8.90662927e+01, 6.60608877e+02, 8.99412600e+02, 1.08223079e+03,
#         1.29512595e+03],
#        [8.89106473e+02, 2.56619702e+02, 3.85418995e-08, 8.12962758e-11,
#         1.28707516e-10]])
